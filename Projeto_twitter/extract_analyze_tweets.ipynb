# %% [markdown]
# # Extrai tweets

# %%
# !python get_tweets.py

# %% [markdown]
# # Entendendo a estrutura do JSON

# %%
import json

# %%
# Abrir o arquivo de tweets e ler as linhas
with open('collected_tweets2020-11-22-15-33-21.txt', 'r') as file:
    tweets = file.readlines()

# %%
# Parse do tweet para json e exporta arquivo
with open('tweet.json', 'w') as json_file:
    json.dump(
        json.loads(
            json.loads(tweets[0])
        ), json_file
    )

# %%
parsed_tweets = [json.loads(json.loads(i)) for i in tweets]

# %%
# quantidade de tweets coletados
len(parsed_tweets)
# Out:
# 3493

# %% [markdown]
# # Acessando as chaves do JSON

# %%
first_tweet = parsed_tweets[0]

# %%
# Chave de primeiro nivel (root)
first_tweet['text']
# Out:
# 'Stay in president Trump let the constitution fairly pick president'

# %%
# Cessando o scren_name do user
first_tweet['user']['screen_name']
# Out:
# 'eddiefisher357'

# %% [markdown]
# # Transformar os tweets em uma estrutura relacional

# %%
import pandas as pd

# %%
df_tratado = pd.DataFrame(first_tweet).reset_index(drop=True).iloc[:1]
df_tratado
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Nov 22 18:33:17 +0000 2020  1330580125314904068  1330580125314904068
#
#                                                 text  \
# 0  Stay in president Trump let the constitution f...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ... quote_count reply_count retweet_count  \
# 0                    None  ...           0           0             0
#
#   favorite_count entities favorited  retweeted filter_level lang  \
# 0              0      NaN     False      False          low   en
#
#     timestamp_ms
# 0  1606069997515
#
# [1 rows x 31 columns]

# %%
df_tratado.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'quoted_status_id', 'quoted_status_id_str',
#        'quoted_status', 'quoted_status_permalink', 'is_quote_status',
#        'quote_count', 'reply_count', 'retweet_count', 'favorite_count',
#        'entities', 'favorited', 'retweeted', 'filter_level', 'lang',
#        'timestamp_ms'],
#       dtype='object')

# %%
df_tratado.drop(columns =['quote_count' , 'reply_count', 'retweet_count', 'favorite_count',
                         'favorited', 'retweeted', 'user', 'entities'], inplace=True)

# %%
df_tratado.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'geo', 'coordinates', 'place',
#        'contributors', 'quoted_status_id', 'quoted_status_id_str',
#        'quoted_status', 'quoted_status_permalink', 'is_quote_status',
#        'filter_level', 'lang', 'timestamp_ms'],
#       dtype='object')

# %%
first_tweet['user']
# Out:
# {'id': 1014279595787464706,
#  'id_str': '1014279595787464706',
#  'name': 'Eddie Fisher',
#  'screen_name': 'eddiefisher357',
#  'location': 'Denison, TX',
#  'url': None,
#  'description': 'Texas',
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 35,
#  'friends_count': 88,
#  'listed_count': 0,
#  'favourites_count': 5393,
#  'statuses_count': 4202,
#  'created_at': 'Tue Jul 03 22:47:54 +0000 2018',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': '000000',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_link_color': '1B95E0',
#  'profile_sidebar_border_color': '000000',
#  'profile_sidebar_fill_color': '000000',
#  'profile_text_color': '000000',
#  'profile_use_background_image': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1014321000404488192/F2ruyH-a_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1014321000404488192/F2ruyH-a_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1014279595787464706/1530658313',
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': None,
#  'follow_request_sent': None,
#  'notifications': None}

# %%
df_tratado['user_id'] = tweet['user']['id']
df_tratado['user_id_str'] = tweet['user']['id_str']
df_tratado['user_screen_name'] = tweet['user']['screen_name']
df_tratado['user_location'] = tweet['user']['location']
df_tratado['user_description'] = tweet['user']['description']
df_tratado['user_protected'] = tweet['user']['protected']
df_tratado['user_verified'] = tweet['user']['verified']
df_tratado['user_followers_count'] = tweet['user']['followers_count']
df_tratado['user_friends_count'] = tweet['user']['friends_count']
df_tratado['user_created_at'] = tweet['user']['created_at']

# %%
df_tratado
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Nov 22 18:33:17 +0000 2020  1330580125314904068  1330580125314904068
#
#                                                 text  \
# 0  Stay in president Trump let the constitution f...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...              user_id          user_id_str  \
# 0                    None  ...  1014279595787464706  1014279595787464706
#
#   user_screen_name user_location user_description  user_protected  \
# 0   eddiefisher357   Denison, TX            Texas           False
#
#   user_verified user_followers_count user_friends_count  \
# 0         False                   35                 88
#
#                   user_created_at
# 0  Tue Jul 03 22:47:54 +0000 2018
#
# [1 rows x 33 columns]

# %%
# Entidades
first_tweet['entities']
# Out:
# {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []}

# %%
user_mentions = []

for i in range(len(first_tweet['entities'][ 'user_mentions'])):
    dicionariobase = first_tweet['entities']['user_mentions'][i].copy()
    dicionariobase.pop('indices', None)
    df = pd.DataFrame(dicionariobase, index=[0])
    df=df.rename(columns={
        'screen_name': 'entities_screen_name',
        'name': 'entities_id',
        'id_str': 'entities_id_str'
    })
    user_mentions.append(df)

# %%
if len(user_mentions) > 0:
    dfs = []
    for i in user_mentions:
        dfs.append(
            pd.concat([df_tratado.copy(), i], axis = 1)
        )
    pd.concat(dfs, ignore_index=True)

# %% [markdown]
# Criar função que faz todo o tratamento do tweet e converte para um DF

# %%
def tweet_para_df(tweet):
    try:
        df_tratado = pd.DataFrame(tweet).reset_index(drop=True).iloc[:1]
        df_tratado.drop(columns =['quote_count' , 'reply_count', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'user', 'entities', 'retweeted_status'], inplace=True)
        df_tratado['user_id'] = tweet['user']['id']
        df_tratado['user_id_str'] = tweet['user']['id_str']
        df_tratado['user_screen_name'] = tweet['user']['screen_name']
        df_tratado['user_location'] = tweet['user']['location']
        df_tratado['user_description'] = tweet['user']['description']
        df_tratado['user_protected'] = tweet['user']['protected']
        df_tratado['user_verified'] = tweet['user']['verified']
        df_tratado['user_followers_count'] = tweet['user']['followers_count']
        df_tratado['user_friends_count'] = tweet['user']['friends_count']
        df_tratado['user_created_at'] = tweet['user']['created_at']

        user_mentions = []

        for i in range(len(tweet['entities'][ 'user_mentions'])):
            dicionariobase = tweet['entities']['user_mentions'][i].copy()
            dicionariobase.pop('indices', None)
            df = pd.DataFrame(dicionariobase, index=[0])
            df=df.rename(columns={
                'screen_name': 'entities_screen_name',
                'name': 'entities_id',
                'id': 'entities_id',
                'id_str': 'entities_id_str'
            })
            user_mentions.append(df)

        dfs = []
        for i in user_mentions:
            dfs.append(
                pd.concat([df_tratado.copy(), i], axis = 1)
            )

        df_final = pd.concat(dfs, ignore_index=True)
        
    except:
        return None

    return df_final

# %%
# %%time
# Iterar e transformar todos os tweets

parseados = [tweet_para_df(tweet) for tweet in parsed_tweets]
# Out:
# CPU times: user 30.2 s, sys: 3.94 ms, total: 30.2 s
# Wall time: 30.2 s

# %%
# Eliminar as posições vazias da lista
new_parseados = [i for i in parseados if (i is not None) and (i.shape[1] == 37)]

# %%
tratado = pd.concat(new_parseados, ignore_index=True)

# %%
tratado
# Out:
#                          created_at                   id               id_str  \
# 0    Sun Nov 22 18:33:17 +0000 2020  1330580126061346816  1330580126061346816
# 1    Sun Nov 22 18:33:17 +0000 2020  1330580126006972423  1330580126006972423
# 2    Sun Nov 22 18:33:17 +0000 2020  1330580125855977478  1330580125855977478
# 3    Sun Nov 22 18:33:17 +0000 2020  1330580125855977478  1330580125855977478
# 4    Sun Nov 22 18:33:17 +0000 2020  1330580125834833920  1330580125834833920
# ..                              ...                  ...                  ...
# 586  Sun Nov 22 18:34:25 +0000 2020  1330580408690483202  1330580408690483202
# 587  Sun Nov 22 18:34:25 +0000 2020  1330580411295162370  1330580411295162370
# 588  Sun Nov 22 18:34:25 +0000 2020  1330580411299360768  1330580411299360768
# 589  Sun Nov 22 18:34:25 +0000 2020  1330580411475398664  1330580411475398664
# 590  Sun Nov 22 18:34:25 +0000 2020  1330580412498907143  1330580412498907143
#
#                                                   text  \
# 0    RT @gtconway3d: Everything people are describi...
# 1    RT @stillgray: He’s right, of course. The purp...
# 2    RT @Females4DJT: President Trump delivers the ...
# 3    RT @Females4DJT: President Trump delivers the ...
# 4    RT @AmoneyResists: We can heal America by hold...
# ..                                                 ...
# 586  RT @DudaPhillis: From the servers seized in Fr...
# 587  RT @mhmck: The Putin-Trump regime deploys titu...
# 588  RT @AmoneyResists: We can heal America by hold...
# 589  RT @hig68: This op ed is insane for the follow...
# 590  RT @GalacticRedPill: Paul Ryan left office in ...
#
#                                                 source  truncated  \
# 0    <a href="http://twitter.com/download/android" ...      False
# 1    <a href="http://twitter.com/download/android" ...      False
# 2    <a href="http://twitter.com/download/android" ...      False
# 3    <a href="http://twitter.com/download/android" ...      False
# 4    <a href="https://mobile.twitter.com" rel="nofo...      False
# ..                                                 ...        ...
# 586  <a href="http://twitter.com/download/iphone" r...      False
# 587  <a href="http://twitter.com/download/iphone" r...      False
# 588  <a href="http://twitter.com/download/iphone" r...      False
# 589  <a href="http://twitter.com/download/iphone" r...      False
# 590  <a href="http://twitter.com/#!/download/ipad" ...      False
#
#     in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                    None                      None                None
# 1                    None                      None                None
# 2                    None                      None                None
# 3                    None                      None                None
# 4                    None                      None                None
# ..                    ...                       ...                 ...
# 586                  None                      None                None
# 587                  None                      None                None
# 588                  None                      None                None
# 589                  None                      None                None
# 590                  None                      None                None
#
#     in_reply_to_user_id_str  ...  \
# 0                      None  ...
# 1                      None  ...
# 2                      None  ...
# 3                      None  ...
# 4                      None  ...
# ..                      ...  ...
# 586                    None  ...
# 587                    None  ...
# 588                    None  ...
# 589                    None  ...
# 590                    None  ...
#
#                                       user_description user_protected  \
# 0                                                 None          False
# 1                                                 None          False
# 2    also known as Texas Lady currently banned for ...          False
# 3    also known as Texas Lady currently banned for ...          False
# 4                                                 None          False
# ..                                                 ...            ...
# 586  “Trust gets you killed,love gets you hurt and ...          False
# 587                                               None          False
# 588  single mother of 5 /ally🌈/ mortgage master💵DV ...          False
# 589  #NotMyPresident 🌊🌊 💯Democrat ❄️ Resist🦋 #wtp20...          False
# 590  MAGA, Conservative Christian, Patriot, 2nd, Tr...          False
#
#     user_verified user_followers_count user_friends_count  \
# 0           False                   21                 99
# 1           False                   82                 89
# 2           False                 1284               1224
# 3           False                 1284               1224
# 4           False                 2236                603
# ..            ...                  ...                ...
# 586         False                 5183               5205
# 587         False                    3                125
# 588         False                   90                348
# 589         False                20910              20740
# 590         False                 3669               4072
#
#                     user_created_at entities_screen_name  \
# 0    Sun Jan 06 06:13:46 +0000 2019           gtconway3d
# 1    Mon May 27 20:26:00 +0000 2013            stillgray
# 2    Tue Jul 28 23:08:38 +0000 2020          Females4DJT
# 3    Tue Jul 28 23:08:38 +0000 2020      realDonaldTrump
# 4    Mon Dec 07 17:11:25 +0000 2015        AmoneyResists
# ..                              ...                  ...
# 586  Sat Jun 04 23:11:10 +0000 2016                POTUS
# 587  Sat Oct 02 00:32:31 +0000 2010                mhmck
# 588  Wed Sep 30 04:03:03 +0000 2020        AmoneyResists
# 589  Sat Jun 04 20:36:54 +0000 2016                hig68
# 590  Fri Oct 12 03:14:47 +0000 2012      GalacticRedPill
#
#                                      entities_id          entities_id  \
# 0                                  George Conway            471677441
# 1                               Ian Miles Cheong             16106584
# 2      President Elect Sheri - EMMY AWARD WINNER  1091293919458086913
# 3                                Donald J. Trump             25073877
# 4                            Andrew Wortman 🏳️‍🌈   739844197935644672
# ..                                           ...                  ...
# 586                              President Trump   822215679726100480
# 587                               Michael MacKay           2415072836
# 588                          Andrew Wortman 🏳️‍🌈   739844197935644672
# 589  MRS HIG RN Karma is here for the GOP 🏳️‍🌈 🌊           2675241528
# 590                              GalacticRedPill   930233510165491712
#
#          entities_id_str
# 0              471677441
# 1               16106584
# 2    1091293919458086913
# 3               25073877
# 4     739844197935644672
# ..                   ...
# 586   822215679726100480
# 587           2415072836
# 588   739844197935644672
# 589           2675241528
# 590   930233510165491712
#
# [591 rows x 37 columns]
